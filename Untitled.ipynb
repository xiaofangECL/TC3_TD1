# %%
# question 2.1

import csv;

with open("regularite-mensuelle-tgv.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    for row in reader:
        print('; '.join(row))
# Out:
# Date; Axe; Départ; Arrivée; Nombre de trains programmés; Nombre de trains ayant circulé; Nombre de trains annulés; Nombre de trains en retard à l'arrivée; Régularité; Commentaires
# 2014-03; Nord; PARIS NORD; DOUAI; 196; 196; 0; 11; 94.4;
# 2014-03; Sud-Est; PARIS LYON; GRENOBLE; 259; 259; 0; 21; 91.9;
# 2014-03; Atlantique; LAVAL; PARIS MONTPARNASSE; 243; 243; 0; 14; 94.2;
# 2014-03; Atlantique; PARIS MONTPARNASSE; ANGERS SAINT LAUD; 435; 435; 0; 25; 94.3;
# ...

# %%
# question 3.1 
import sqlite3
conn = sqlite3.connect('sncf.sqlite')

# %%
# question 3.2
c = conn.cursor()
c.execute("DROP TABLE IF EXISTS regularite_tgv")
c.execute("CREATE TABLE regularite_tgv (id INTEGER PRIMARY KEY, annee INTEGER, mois INTEGER, axe, depart, arrivee, \
          nb_prevus INTEGER, nb_trains INTEGER, nb_annules INTEGER, nb_retards INTEGER, regularite REAL, commentaire)")

conn.commit()

# %%
# question 3.3

# %%
# 4.1
# remplissage de la table
with open("regularite-mensuelle-tgv.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    got_header = False
    for row in reader:
        # on ignore la ligne d'entête
        if ( not got_header ):
            got_header = True
            continue
        annee, mois = row[0].split(sep='-')
        c.execute('INSERT INTO regularite_tgv VALUES (NULL, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)',
                  (annee, mois)+tuple(v for v in row[1:]))
        conn.commit()

# %%
# 4.2
# on nettoie avant de remplir
c.execute('DELETE FROM regularite_tgv')
conn.commit()

# %%
# 4.3
# on nettoie avant de remplir
c.execute('DELETE FROM regularite_tgv')
conn.commit()

# on note l'heure
import time
start = time.time()

# on remplit la table
with open("regularite-mensuelle-tgv.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    got_header = False
    for row in reader:
        # on ignore la ligne d'entête
        if ( not got_header ):
            got_header = True
            continue
        annee, mois = row[0].split(sep='-')
        c.execute('INSERT INTO regularite_tgv VALUES (NULL, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)',
                  (annee, mois)+tuple(v for v in row[1:]))
        conn.commit()

# on affiche le temps passé
print("Temps de chargement {:.2f} secondes".format(time.time()-start))
# Out:
# Temps de chargement 5.32 secondes

# %%
# test row_factory

# %%
# 5.1
#5.1 - Ecrivez un programme Python qui affiche le nombre d'enregistrements dans la table.
c.execute('SELECT COUNT(*) FROM regularite_tgv')
r = c.fetchone()
print(r[0])
# Out:
# 4600

# %%
# test row factory
conn.row_factory=sqlite3.Row
c=conn.cursor()
c.execute('SELECT * FROM regularite_tgv')
r=c.fetchone()
type(r)
print(r.keys())
r['annee']
# Out:
# ['id', 'annee', 'mois', 'axe', 'depart', 'arrivee', 'nb_prevus', 'nb_trains', 'nb_annules', 'nb_retards', 'regularite', 'commentaire']
# 2014

# %%
# 5.2  5.2 - Ecrivez un programme Python qui affiche le nombre d'axes TGV cités dans la base ?
c.execute('SELECT COUNT(DISTINCT axe) FROM regularite_tgv')
r = c.fetchone()
print(r[0])
# Out:
# 4

# %%
# 5.2 test row_factory
c.execute('SELECT COUNT(DISTINCT axe) FROM regularite_tgv')
r=c.fetchone()
r.keys()
print(r['COUNT(DISTINCT axe)'])
# Out:
# 4

# %%
# 5.3 - Ecrivez un programme Python qui affiche la liste des axes TGV cités dans la base.
c.execute('SELECT DISTINCT axe FROM regularite_tgv')
r = c.fetchall()
print([a[0] for a in r])
# Out:
# ['Nord', 'Sud-Est', 'Atlantique', 'Est']

# %%
# with row_factory
c.execute('SELECT DISTINCT axe FROM regularite_tgv')
r=c.fetchall()
for i in range(len(r)):
    print(r[i]['axe'])
#print(a['axe'] for a in r)
# Out:
# Nord
# Sud-Est
# Atlantique
# Est

# %%
# 5.4 - Ecrivez un programme Python qui affiche le nombre et la liste des gares de départ sur l'axe Sud-Est.
c.execute("SELECT DISTINCT depart FROM regularite_tgv WHERE axe='Sud-Est'")
r = c.fetchall()
print(len(r),[a[0] for a in r])
# Out:
# 21 ['PARIS LYON', 'MONTPELLIER', 'VALENCE ALIXAN TGV', 'CHAMBERY CHALLES LES EAUX', 'GRENOBLE', 'LYON PART DIEU', 'MULHOUSE VILLE', 'PERPIGNAN', 'AIX EN PROVENCE TGV', 'NICE VILLE', 'ANNECY', 'BELLEGARDE (AIN)', 'MACON LOCHE', 'AVIGNON TGV', 'MARSEILLE ST CHARLES', 'DIJON VILLE', 'TOULON', 'LE CREUSOT MONTCEAU MONTCHANIN', 'SAINT ETIENNE CHATEAUCREUX', 'BESANCON FRANCHE COMTE TGV', 'NIMES']

# %%
conn.row_factory=sqlite3.Row
c=conn.cursor()
c.execute("SELECT DISTINCT depart FROM regularite_tgv WHERE axe='Sud-Est'")
r=c.fetchall()
print(len(r))
for i in range(len(r)):
    print(r[i]['depart'])
# Out:
# 21
# PARIS LYON
# MONTPELLIER
# VALENCE ALIXAN TGV
# CHAMBERY CHALLES LES EAUX
# GRENOBLE
# LYON PART DIEU
# MULHOUSE VILLE
# PERPIGNAN
# AIX EN PROVENCE TGV
# NICE VILLE
# ANNECY
# BELLEGARDE (AIN)
# MACON LOCHE
# AVIGNON TGV
# MARSEILLE ST CHARLES
# DIJON VILLE
# TOULON
# LE CREUSOT MONTCEAU MONTCHANIN
# SAINT ETIENNE CHATEAUCREUX
# BESANCON FRANCHE COMTE TGV
# NIMES

# %%
# 5.5 - Ecrivez un programme Python qui affiche le nombre de trains au départ de Paris Gare de Lyon en 2014.
c.execute("SELECT SUM(nb_trains) FROM regularite_tgv WHERE depart='PARIS LYON' AND annee=2014")
r = c.fetchone()

# et qu'on ne me demande pas pourquoi r[0] est un réel, car je n'en sais rien ...
print(int(r[0]))
# Out:
# 68184

# %%
c.execute("SELECT SUM(nb_trains) FROM regularite_tgv WHERE depart='PARIS LYON' AND annee=2014")
r = c.fetchone()
r.keys()
print(int(r['SUM(nb_trains)']))
# Out:
# 68184

# %%
# 5.6 - Ecrivez un programme Python qui affiche le nombre de trains partis de Paris Gare de Lyon en 2014 
#et arrivés avec du retard.
c.execute("SELECT SUM(nb_retards) FROM regularite_tgv WHERE depart='PARIS LYON' AND annee=2014")
r = c.fetchone()
print(r[0])

# %%
c.execute("SELECT SUM(nb_retards) FROM regularite_tgv WHERE depart='PARIS LYON' AND annee=2014")
r = c.fetchone()
print(int(r['SUM(nb_retards)']))
# Out:
# 5604

# %%
# 5.7 - Ecrivez un programme Python qui affiche le nombre de trains annulés au départ de Paris Gare de Lyon en 2014.
c.execute("SELECT SUM(nb_annules) FROM regularite_tgv WHERE depart='PARIS LYON' AND annee=2014")
r = c.fetchone()
print(r[0])

# %%
# 5.8 - Ecrivez un programme Python qui affiche le contenu de la table regularite_tgv mois par mois, 
#dans l'ordre, au départ de Paris Gare de Lyon, vers Lyon Part Dieu.
c.execute("SELECT * FROM regularite_tgv WHERE depart='PARIS LYON' and arrivee='LYON PART DIEU' ORDER By annee,mois")
a = c.fetchall()
for r in a:
    print(r)

# %%
c = conn.cursor()
c.execute("SELECT * FROM regularite_tgv WHERE depart='PARIS LYON' and arrivee='LYON PART DIEU' ORDER By annee,mois")
a = c.fetchall()
print(a[0].keys())
for i in range(len(a)):
    d=[]
    for j in a[i].keys():
        d.append(a[i][j])
    print(d)
# Out:
# ['id', 'annee', 'mois', 'axe', 'depart', 'arrivee', 'nb_prevus', 'nb_trains', 'nb_annules', 'nb_retards', 'regularite', 'commentaire']
# [3114, 2011, 9, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 637, 637, 0, 55, 91.4, '']
# [3406, 2011, 10, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 647, 646, 1, 40, 93.8, '']
# [1036, 2011, 11, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 627, 627, 0, 40, 93.6, '']
# [3451, 2011, 12, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 615, 615, 0, 21, 96.6, '']
# [389, 2012, 1, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 631, 631, 0, 23, 96.4, '']
# [3484, 2012, 2, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 602, 600, 2, 45, 92.5, '']
# [831, 2012, 3, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 638, 638, 0, 19, 97.0, '']
# [3773, 2012, 4, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 615, 612, 3, 25, 95.9, '']
# [3667, 2012, 5, 'Sud-Est', 'PARIS LYON', 'LYON PART DIEU', 625, 623, 2, 35, 94.4, '']
# ...

# %%
# 5.9 - En vous référant au tutoriel pyplot, tracez la courbe de régularité correspondant à ces données. 
# pour le tracé de la courbe
import matplotlib.pyplot as plt
# %matplotlib inline

x = [n for n in range(len(a))]
y = [r[10] for r in a]

plt.figure(figsize=(18,3))
plt.ylim(80,100)
plt.grid(True)
plt.plot(x,y)
plt.show()

# %%
# 5.9 object de row_factory
import matplotlib.pyplot as plt
x=range(0,len(a))
y=[a[i]['regularite'] for i in range(len(a))]
plt.figure(figsize=(18,3))
plt.ylim(80,100)
plt.grid(True)
plt.plot(x,y)
plt.show()

# %%
#5.10 - Consultez le tutoriel et la doc, puis retracez ce graphique avec un titre 
# et un axe des abscisses correctement annoté (mois et années). 
mois = ['Jan','Fév','Mar','Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sept', 'Oct', 'Nov', 'Déc']
xticks = [n*4 for n in range(int(len(a)/4)+1)]
xlabels = ['{} {}'.format(mois[r[2]-1], r[1]) for r in [a[t] for t in xticks]]

plt.figure(figsize=(18,4))
plt.ylim(80,100)
plt.grid(which='major', color='#888888', linestyle='-')
plt.grid(which='minor',axis='x', color='#888888', linestyle=':')
plt.title('Régularité des TGV (en %) au départ de Paris Gare de Lyon, à destination de Lyon Part Dieu',fontsize=16)

ax = plt.subplot(111)
ax.set_xticks(xticks)
ax.set_xticks(x, minor=True)
ax.set_xticklabels(xlabels, fontsize=12)

plt.plot(x,y)
plt.show()

# %%
# 5.10
mois = ['Jan','Fév','Mar','Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sept', 'Oct', 'Nov', 'Déc']
xticks = [n*4 for n in range(int(len(a)/4)+1)]
xlabels=['{} {}'.format(mois[a[i]['mois']-1],a[i]['annee']) for i in xticks]

print(xticks)
print(xlabel)
plt.figure(figsize=(18,4))
plt.ylim(80,100)
plt.grid(which='major', color='#888888', linestyle='-')
plt.grid(which='minor',axis='x', color='#888888', linestyle=':')
plt.title('Régularité des TGV (en %) au départ de Paris Gare de Lyon, à destination de Lyon Part Dieu',fontsize=16)

ax = plt.subplot(111)
ax.set_xticks(xticks)
ax.set_xticks(x, minor=True)
ax.set_xticklabels(xlabels, fontsize=12)

plt.plot(x,y)
plt.show()
# Out:
# [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44]
# ['Oct 2011', 'Fév 2012', 'Juin 2012', 'Oct 2012', 'Fév 2013', 'Juin 2013', 'Oct 2013', 'Fév 2014', 'Juin 2014', 'Oct 2014', 'Fév 2015', 'Juin 2015']

# %%
# 5.11 - Le résultat n'étant pas très esthétique, pourquoi ne pas essayer d'afficher 
# les points de mesure superposés à une courbe dérivable ? Voyez la doc puis retracez cette courbe en interpolant 
# une dizaine de points entre deux points de mesure à l'aide d'une fonction spline. 
# pour la fonction d'interpolation

import numpy as np
from scipy import interpolate

spl = interpolate.splrep(x, y, s=0)

x2 = [n/10 for n in range(10*(len(a)-1)+1)]
y2 = interpolate.splev(x2, spl, der=0)

plt.figure(figsize=(18,4))
plt.ylim(80,100)
plt.grid(which='major', color='#888888', linestyle='-')
plt.grid(which='minor',axis='x', color='#888888', linestyle=':')
plt.title('Régularité des TGV (en %) au départ de Paris Gare de Lyon, à destination de Lyon Part Dieu',fontsize=16)

ax = plt.subplot(111)
ax.set_xticks(xticks)
ax.set_xticks(x, minor=True)
ax.set_xticklabels(xlabels, fontsize=12)

plt.plot(x,y,'r^',x2,y2,'#aaaaaa')
plt.show()

# %%
import numpy as np
from scipy import interpolate

spl = interpolate.splrep(x, y, s=0) # equation mathematique y=f(x)
x2 = [n/10 for n in range(10*(len(a)-1)+1)] # 
y2 = interpolate.splev(x2, spl, der=0)

plt.figure(figsize=(18,4))
plt.ylim(80,100)
plt.grid(which='major', color='#888888', linestyle='-')
plt.grid(which='minor',axis='x', color='#888888', linestyle=':')
plt.title('Régularité des TGV (en %) au départ de Paris Gare de Lyon, à destination de Lyon Part Dieu',fontsize=16)

ax = plt.subplot(111)
ax.set_xticks(xticks)
ax.set_xticks(x, minor=True)
ax.set_xticklabels(xlabels, fontsize=12)

plt.plot(x,y,'r^',x2,y2,'olive')
plt.show()

# %%
# 5.12 - Affichez l'ensemble des commentaires (dernier champ de la table) pour les TVG concernés par cette courbe.
c.execute("SELECT * FROM regularite_tgv WHERE depart='PARIS LYON' AND arrivee='LYON PART DIEU' AND commentaire<>'' \
           ORDER By annee,mois")
a = c.fetchall()
for r in a:
    print('{} {} : {}'.format(mois[r[2]-1],r[1],r[11]))
# Out:
# Mar 2013 : La journée du 12 mars a été très perturbée par les intempéries (neige et pluies verglassantes) entrainant de nombreux et importants retards avoisinants les 2 heures.

# %%
c.execute("SELECT * FROM regularite_tgv WHERE depart='PARIS LYON' AND arrivee='LYON PART DIEU' AND commentaire<>'' \
           ORDER By annee,mois")
a = c.fetchall()
for i in range(len(a)):
   print('{} {}: {}'.format( mois[a[i]['mois']-1],a[i]['annee'],a[i]['commentaire']))
# Out:
# Mar 2013: La journée du 12 mars a été très perturbée par les intempéries (neige et pluies verglassantes) entrainant de nombreux et importants retards avoisinants les 2 heures.

# %%
# 6.1 - Créez une table ponctualite_transilien :
# suppression de la table si elle existe
c.execute("DROP TABLE IF EXISTS ponctualite_transilien")

# création de la table
c.execute("CREATE TABLE ponctualite_transilien (id INTEGER PRIMARY KEY, annee INTEGER, mois INTEGER, id_ligne, type_ligne, \
          code_ligne, nom_ligne, ponctualite REAL)")

# remplissage de la table
start = time.time()
with open("ponctualite-mensuelle-transilien.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    got_header = False
    for row in reader:
        # on ignore la ligne d'entête
        if ( not got_header ):
            got_header = True
            continue
        annee, mois = row[1].split(sep='-')
        c.execute('INSERT INTO ponctualite_transilien VALUES (NULL, ?, ?, ?, ?, ?, ?, ?)', (annee, mois,row[0])+tuple(v for v in row[2:6]))
        conn.commit()

# affichage du temps passé
print("Temps de chargement {:.2f} secondes".format(time.time()-start))

# %%
c.execute("DROP TABLE IF EXISTS ponctualite_transilien")
c.execute("CREATE TABLE ponctualite_transilien (id INTEGER PRIMARY KEY, annee INTEGER, mois INTEGER, id_ligne, type_ligne, \
          code_ligne, nom_ligne, ponctualite REAL)")
start = time.time()
with open("ponctualite-mensuelle-transilien.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    got_header = False
    for row in reader:
        # on ignore la ligne d'entête
        if ( not got_header ):
            got_header = True
            continue
        annee, mois = row[1].split(sep='-')
        c.execute('INSERT INTO ponctualite_transilien VALUES (NULL, ?, ?, ?, ?, ?, ?, ?)', (annee, mois,row[0])+tuple(v for v in row[2:6]))
        conn.commit()

# affichage du temps passé
print("Temps de chargement {:.2f} secondes".format(time.time()-start))
# Out:
# Temps de chargement 0.42 secondes

# %%
# 6.2 - Affichez le nombre de lignes (de train) répertoriées dans cette table, 
# et leur liste avec id, type, code et nom correctement formattés.
c.execute("SELECT DISTINCT id_ligne, type_ligne, code_ligne, nom_ligne FROM ponctualite_transilien ORDER BY code_ligne")
r = c.fetchall()
print(len(r))
for a in r:
    print('{:6s} {:10s} {} {}'.format(*a))

# %%
# 6.3 - Créez une table couleur_transilien :
# suppression de la table si elle existe
c.execute("DROP TABLE IF EXISTS couleur_transilien")

# création de la table
c.execute("CREATE TABLE couleur_transilien (id INTEGER PRIMARY KEY, code_ligne, \
          couleur, rouge INTEGER, vert INTEGER, bleu INTEGER, hexadecimal)")

# remplissage de la table
start = time.time()
with open("code-couleur-transilien.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    got_header = False
    for row in reader:
        # on ignore la ligne d'entête
        if ( not got_header ):
            got_header = True
            continue
        junk, code = row[0].split(sep=' ')
        c.execute('INSERT INTO couleur_transilien VALUES (NULL, ?, ?, ?, ?, ?, ?)', (code,)+tuple(v for v in row[1:]))
        conn.commit()

print("Temps de chargement {:.2f} secondes".format(time.time()-start))
# Out:
# Temps de chargement 0.01 secondes

# %%
# 6.4 - Tracez un graphique superposant les courbes de ponctualité des lignes de RER en respectant les couleurs.
#Attention à corriger au mieux l'absence d'information (il y a une valeur de ponctualité manquante pour le RER B).
# Exemple de résultat : 
# liste des lignes de RER avec leur code couleur

c.execute("SELECT DISTINCT ponctualite_transilien.code_ligne, couleur_transilien.hexadecimal \
           FROM ponctualite_transilien, couleur_transilien \
           WHERE ponctualite_transilien.code_ligne = couleur_transilien.code_ligne \
           AND type_ligne = 'RER' \
           ORDER BY ponctualite_transilien.code_ligne")
lignes = c.fetchall()

# configuration du tracé
plt.figure(figsize=(18,6))
plt.ylim(65,100)
plt.grid(True)

# boucle sur les lignes
for l in (lignes):
    c.execute("SELECT ponctualite_transilien.* \
               FROM ponctualite_transilien \
               WHERE ponctualite_transilien.code_ligne = ? \
               ORDER BY annee, mois",l[0])
    a = c.fetchall()

    # il y a une valeur manquante pour le RER B
    x = [n for n in range(len(a)) if not a[n][7] == '']
    y = [r[7] for r in a if not r[7] == '']

    # interpolation spline
    spl = interpolate.splrep(x, y, s=0)
    x2 = [n/10 for n in range(10*(len(a)-1)+1)]
    y2 = interpolate.splev(x2, spl, der=0)

    # tracé de la courbe de régularité
    plt.plot(x2,y2,linewidth=2,color=l[1], label='RER '+l[0])
    plt.plot(x,y,linewidth=0,marker='s',markeredgecolor='w',markerfacecolor=l[1],markersize=10)
    
# configuration du tracé (titre, grille)
plt.grid(which='major', color='#888888', linestyle='-')
plt.grid(which='minor',axis='x', color='#888888', linestyle=':')
plt.title('Ponctualité des lignes RER (en %)',fontsize=16)

# configuration de l'axe du temps
mois = ['Jan','Fév','Mar','Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sept', 'Oct', 'Nov', 'Déc']
xticks = [n*4 for n in range(int(len(a)/4))]
xlabels = ['{} {}'.format(mois[r[2]-1], r[1]) for r in [a[t] for t in xticks]]

plt.xlim(0,len(a)-1)
ax = plt.subplot(111)
ax.set_xticks(xticks)
ax.set_xticks(x, minor=True)
ax.set_xticklabels(xlabels, fontsize=12)

# légende
plt.legend(loc='lower left')

plt.show()

# %%
c.execute("SELECT DISTINCT ponctualite_transilien.code_ligne, couleur_transilien.hexadecimal \
           FROM ponctualite_transilien, couleur_transilien \
           WHERE ponctualite_transilien.code_ligne = couleur_transilien.code_ligne \
           AND type_ligne = 'RER' \
           ORDER BY ponctualite_transilien.code_ligne")
lignes = c.fetchall()
for i in range(len(lignes)):
    d=[]
    for j in lignes[i].keys():
        d.append(lignes[i][j])
    print(d)
    
for l in (lignes):
    c.execute("SELECT ponctualite_transilien.* \
               FROM ponctualite_transilien \
               WHERE ponctualite_transilien.code_ligne = ? \
               ORDER BY annee, mois",l[0])
    
    a = c.fetchall()
    x = [n for n in range(len(a)) if not a[n]['pontualite'] == '']
    y = [a[i]['pontualite'] for i in range(len(a)) if not a[i]['pontualite'] == '']
    print(x)
    print(a[0].keys())
    for i in range(len(a)):
        d=[]
        for j in a[i].keys():
            d.append(a[i][j])
        print(d)
# Out:
# ['A', '#D1302F']
# ['B', '#427DBD']
# ['C', '#FCD946']
# ['D', '#5E9620']
# ['E', '#BD76A1']
# ['id', 'annee', 'mois', 'id_ligne', 'type_ligne', 'code_ligne', 'nom_ligne', 'ponctualite']
# [1, 2013, 1, 'TRA_1', 'RER', 'A', 'RER A', 83.6]
# [182, 2013, 2, 'TRA_1', 'RER', 'A', 'RER A', 86.2]
# [333, 2013, 3, 'TRA_1', 'RER', 'A', 'RER A', 84.0]
# [9, 2013, 4, 'TRA_1', 'RER', 'A', 'RER A', 83.3]
# [339, 2013, 5, 'TRA_1', 'RER', 'A', 'RER A', 86.4]
# [190, 2013, 6, 'TRA_1', 'RER', 'A', 'RER A', 83.4]
# [282, 2013, 7, 'TRA_1', 'RER', 'A', 'RER A', 83.2]
# [16, 2013, 8, 'TRA_1', 'RER', 'A', 'RER A', 88.9]
# [111, 2013, 9, 'TRA_1', 'RER', 'A', 'RER A', 83.3]
# [351, 2013, 10, 'TRA_1', 'RER', 'A', 'RER A', 83.1]
# [115, 2013, 11, 'TRA_1', 'RER', 'A', 'RER A', 80.9]
# [204, 2013, 12, 'TRA_1', 'RER', 'A', 'RER A', 81.2]
# [208, 2014, 1, 'TRA_1', 'RER', 'A', 'RER A', 81.1]
# [37, 2014, 2, 'TRA_1', 'RER', 'A', 'RER A', 85.7]
# [300, 2014, 3, 'TRA_1', 'RER', 'A', 'RER A', 83.3]
# ...
